# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = gpd.read_file('./data/1201_sample_data/sig.shp', encoding='utf-8')

# %%
data
# Out:
#     SIG_CD    SIG_ENG_NM       SIG_KOR_NM  \
# 0    11110     Jongno-gu  b'c1beb7ceb1b8'
# 1    11140       Jung-gu      b'c1dfb1b8'
# 2    11170    Yongsan-gu  b'bfebbbeab1b8'
# 3    11200  Seongdong-gu  b'bcbab5bfb1b8'
# 4    11215   Gwangjin-gu  b'b1a4c1f8b1b8'
# ..     ...           ...              ...
# 245  51790  Hwacheon-gun  b'c8adc3b5b1ba'
# 246  51800    Yanggu-gun  b'bee7b1b8b1ba'
# 247  51810      Inje-gun  b'c0cec1a6b1ba'
# 248  51820   Goseong-gun  b'b0edbcbab1ba'
# 249  51830  Yangyang-gun  b'bee7bee7b1ba'
#
#                                               geometry
# 0    POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1    POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2    POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3    POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4    POLYGON ((964825.058 1952633.250, 964875.565 1...
# ..                                                 ...
# 245  POLYGON ((1027779.614 2032000.017, 1027951.841...
# ...

# %%
seoul = data[data['SIG_CD'].str.startswith('11')]

# %%
seoul.plot()
# Out:
# <Axes: >

# %%
seoul.head()
# Out:
#   SIG_CD    SIG_ENG_NM       SIG_KOR_NM  \
# 0  11110     Jongno-gu  b'c1beb7ceb1b8'
# 1  11140       Jung-gu      b'c1dfb1b8'
# 2  11170    Yongsan-gu  b'bfebbbeab1b8'
# 3  11200  Seongdong-gu  b'bcbab5bfb1b8'
# 4  11215   Gwangjin-gu  b'b1a4c1f8b1b8'
#
#                                             geometry
# 0  POLYGON ((956615.453 1953567.199, 956621.579 1...
# 1  POLYGON ((957890.386 1952616.746, 957909.908 1...
# 2  POLYGON ((953115.761 1950834.084, 953114.206 1...
# 3  POLYGON ((959681.109 1952649.605, 959842.412 1...
# 4  POLYGON ((964825.058 1952633.250, 964875.565 1...

# %%
ax = seoul.plot(column='SIG_CD', legend=False, categorical=True)
ax.set_title('Map of Seoul')
ax.set_axis_off()
plt.show()
